# %%
import numpy as np
import pandas as pd
from pydataset import data
import math

import matplotlib.pyplot as plt

x = np.array(list(range(150)))

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
# y
# =
# x
# 2
# −
# x
# +
# 2
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
def first_y(x):
    return x**2 - x + 2

# %%
plt.plot(first_y(x))
plt.annotate('Intersection', xy=(0, 0),
             arrowprops={'facecolor': 'blue'})
# Out:
# Text(0, 0, 'Intersection')

# %%
#works but updating to functions
"""
x = np.array(list(range(150)))
y = x**2 - x + 2

plt.plot(y)
plt.annotate('Intersection', xy=(0, 0),
             arrowprops={'facecolor': 'blue'})
             
"""

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %% [markdown]
# y = \sqrt{x}
#
# y = x^3
#
# y = 2^x
#
# y = 1/(x+1)

# %%
# x = np.array(list(range(150)))
y = x**2 - x + 2

plt.plot(y)

# %%
'''

question one exapmlle for question 2 and 3

plt.plot(first_y(x))
plt.annotate('Intersection', xy=(0, 0),
             arrowprops={'facecolor': 'blue'})

def first_y(x):
    return x**2 - x + 2

'''
# Out:
# "\n\nplt.plot(first_y(x))\nplt.annotate('Intersection', xy=(0, 0),\n             arrowprops={'facecolor': 'blue'})\n\n"

# %%
def second_y_1(x):
    return np.sqrt(x)

def second_y_2(x):
    return x ** 3

def second_y_3(x):
    return 2 ** x

def second_y_4(x):
    return 1/(x+1)

# %%
plt.plot(second_y_1(x))
# plt.ylim(200,500)
plt.title('y = sqrt{x}')
# Out:
# Text(0.5, 1.0, 'y = sqrt{x}')

# %%
plt.plot(second_y_2(x))
# plt.ylim(200,500)
plt.title('y = x ** 3')
# Out:
# Text(0.5, 1.0, 'y = x ** 3')

# %%
plt.plot(second_y_3(x))
# plt.ylim(200,500)
plt.title('y = 2^x')
# Out:
# Text(0.5, 1.0, 'y = 2^x')

# %%
plt.plot(second_y_4(x))
# plt.ylim(200,500)
plt.title('y = 1/(x+1)')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(14,7))

#define first subplot
plt.subplot(2,2,1)
plt.plot(second_y_1(x))
# plt.ylim(200,500)
plt.title('y = \sqrt{x}')

# Define second subplot
plt.subplot(2,2,2)
plt.plot(second_y_2(x))
# plt.ylim(200,500)
plt.title('y = x^3')

plt.figure(figsize=(14,7))
#define third subplot
plt.subplot(2,2,3)
plt.plot(second_y_3(x))
# plt.ylim(200,500)
plt.title('y = 2^x')

# Define fourth subplot
plt.subplot(2,2,4)
plt.plot(second_y_4(x))
plt.grid(True, ls='--')
# plt.ylim(200,500)
plt.title('y = 1/(x+1)')
# Out:
# Text(0.5, 1.0, 'y = 1/(x+1)')

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.
#
# # these four need to be plotted on the same chart. So I can see contrast of colors on one chart

# %%
plt.figure(figsize=(14,7))

#define first subplot
plt.subplot(2,2,1)
plt.plot(second_y_1(x),  c='yellow', label='x=[1,150]')
# plt.ylim(200,500)
plt.title('y = \sqrt{x}')
plt.legend()

# Define second subplot
plt.subplot(2,2,2)
plt.plot(second_y_2(x), c='red', label='x=[1,150]')
# plt.ylim(200,500)
plt.title('y = x^3')
plt.legend()

plt.figure(figsize=(14,7), label='x=[1,150]')
#define third subplot
plt.subplot(2,2,3)
plt.plot(second_y_3(x), c='blue',label='x=[1,150]')
# plt.ylim(200,500)
plt.title('y = 2^x')
plt.legend()

# Define fourth subplot
plt.subplot(2,2,4)
plt.plot(second_y_4(x),c='green', label='x=[1,150]')
# plt.ylim(200,500)
plt.title('y = 1/(x+1)')
plt.legend()
